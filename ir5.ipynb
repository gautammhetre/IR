# %%
# !pip install networkx matplotlib
# Out:
# Requirement already satisfied: networkx in c:\users\sanjana\anaconda3\lib\site-packages (3.3)
# Requirement already satisfied: matplotlib in c:\users\sanjana\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sanjana\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sanjana\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create a random graph
G = nx.barabasi_albert_graph(10, 3)  # 10 nodes, 3 edges per new node

# %%
# Compute PageRank
pr = nx.pagerank(G, alpha=0.85)
print("PageRank Values:\n", pr)
# Out:
# PageRank Values:
#  {0: 0.15809596813100152, 1: 0.09673302577588418, 2: 0.09594678263710056, 3: 0.096041703212198, 4: 0.1587544517139518, 5: 0.09525377472600237, 6: 0.07490763511143807, 7: 0.07499503706416621, 8: 0.07524157668508433, 9: 0.07403004494317282}

# %%
# Visualize
plt.figure(figsize=(5,5))
nx.draw(G, with_labels=True, node_color='lightblue', node_size=800, font_size=10)
plt.show()
