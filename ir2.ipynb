# %%
# PRACTICAL 2: Inverted Index for Document Retrieval
docs = {
    "Doc1": "The quick brown fox jumped over the lazy dog",
    "Doc2": "The lazy dog slept in the sun"
}

# %%
inverted_index = {}

# %%
for doc, text in docs.items():
    words = text.lower().split()
    for word in words:
        if word not in inverted_index:
            inverted_index[word] = [doc]
        elif doc not in inverted_index[word]:
            inverted_index[word].append(doc)

# %%
print("Inverted Index:")
for term, doc_list in inverted_index.items():
    print(f"{term} -> {', '.join(doc_list)}")
# Out:
# Inverted Index:
# the -> Doc1, Doc2
# quick -> Doc1
# brown -> Doc1
# fox -> Doc1
# jumped -> Doc1
# over -> Doc1
# lazy -> Doc1, Doc2
# dog -> Doc1, Doc2
# slept -> Doc2
# in -> Doc2
# sun -> Doc2
